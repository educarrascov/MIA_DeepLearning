# %%
pip install jupyter_contrib_nbextensions
# Out:
# Collecting jupyter_contrib_nbextensions
#   Downloading jupyter_contrib_nbextensions-0.5.1-py2.py3-none-any.whl (20.9 MB)
#      |████████████████████████████████| 20.9 MB 2.3 MB/s eta 0:00:01
# Collecting lxml
#   Downloading lxml-4.8.0-cp39-cp39-macosx_10_15_x86_64.whl (4.6 MB)
#      |████████████████████████████████| 4.6 MB 8.5 MB/s eta 0:00:01
# Requirement already satisfied: tornado in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (6.1)
# Requirement already satisfied: ipython-genutils in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: nbconvert>=4.2 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (6.1.0)
# Requirement already satisfied: jupyter-core in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (4.7.1)
# Requirement already satisfied: traitlets>=4.1 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (5.0.5)
# Collecting jupyter-latex-envs>=1.3.8
#   Downloading jupyter_latex_envs-1.4.6.tar.gz (861 kB)
#      |████████████████████████████████| 861 kB 421 kB/s eta 0:00:01
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp39-cp39-macosx_10_9_x86_64.whl (197 kB)
#      |████████████████████████████████| 197 kB 30.2 MB/s eta 0:00:01
# Requirement already satisfied: notebook>=4.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (6.4.3)
# Collecting jupyter-contrib-core>=0.3.3
#   Downloading jupyter_contrib_core-0.3.3-py2.py3-none-any.whl (18 kB)
# Collecting jupyter-highlight-selected-word>=0.1.1
#   Downloading jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting jupyter-nbextensions-configurator>=0.4.0
#   Downloading jupyter_nbextensions_configurator-0.4.1.tar.gz (479 kB)
#      |████████████████████████████████| 479 kB 33.2 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (57.4.0)
# Requirement already satisfied: ipython in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (7.26.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: jinja2>=2.4 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (3.0.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.3)
# Requirement already satisfied: testpath in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.1.2)
# Requirement already satisfied: bleach in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (4.0.0)
# Requirement already satisfied: defusedxml in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: nbformat>=4.4 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (5.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jinja2>=2.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (2.0.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=4.2->jupyter_contrib_nbextensions) (7.0.1)
# Requirement already satisfied: nest-asyncio in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=4.2->jupyter_contrib_nbextensions) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=4.2->jupyter_contrib_nbextensions) (22.2.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: six>=1.11.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.18.0)
# Requirement already satisfied: prometheus-client in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.11.0)
# Requirement already satisfied: argon2-cffi in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: ipykernel in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (6.2.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.11.1)
# Requirement already satisfied: ptyprocess in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from terminado>=0.8.3->notebook>=4.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (1.14.6)
# Requirement already satisfied: pycparser in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (2.20)
# Requirement already satisfied: webencodings in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: packaging in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (21.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (1.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (0.1.2)
# Requirement already satisfied: appnope in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (3.0.20)
# Requirement already satisfied: pexpect>4.3 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.18.0)
# Requirement already satisfied: backcall in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: decorator in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (5.0.9)
# Requirement already satisfied: pickleshare in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jedi>=0.16->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.8.2)
# Requirement already satisfied: wcwidth in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from packaging->bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (2.4.7)
# Building wheels for collected packages: jupyter-latex-envs, jupyter-nbextensions-configurator
#   Building wheel for jupyter-latex-envs (setup.py) ... done
#   Created wheel for jupyter-latex-envs: filename=jupyter_latex_envs-1.4.6-py2.py3-none-any.whl size=963414 sha256=5c4ed9915e3c9bc32ad0dd41613c0669f38c03af85cb6e31eb6473eb1e24d90f
#   Stored in directory: /Users/eduardo/Library/Caches/pip/wheels/f7/b5/78/f5b899dd8fc137fe0bfe26b382713f6d171c9eac2fb1fa091f
#   Building wheel for jupyter-nbextensions-configurator (setup.py) ... done
#   Created wheel for jupyter-nbextensions-configurator: filename=jupyter_nbextensions_configurator-0.4.1-py2.py3-none-any.whl size=465843 sha256=0ed1eeacce17d991101485cd6cd0f24418e1faa673e16b458f245e59fed0f5c9
#   Stored in directory: /Users/eduardo/Library/Caches/pip/wheels/94/62/cd/233da8580d4e1228ab3fbede758ab1b97174bf9d9cea095049
# Successfully built jupyter-latex-envs jupyter-nbextensions-configurator
# Installing collected packages: pyyaml, jupyter-contrib-core, lxml, jupyter-nbextensions-configurator, jupyter-latex-envs, jupyter-highlight-selected-word, jupyter-contrib-nbextensions
# Successfully installed jupyter-contrib-core-0.3.3 jupyter-contrib-nbextensions-0.5.1 jupyter-highlight-selected-word-0.2.0 jupyter-latex-envs-1.4.6 jupyter-nbextensions-configurator-0.4.1 lxml-4.8.0 pyyaml-6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
jupyter contrib nbextension install
# Out:
#   File "/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/ipykernel_39470/1996274467.py", line 1
#     jupyter contrib nbextension install
#             ^
# SyntaxError: invalid syntax

# %%
pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
# Out:
# Collecting https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#   Downloading https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#      / 23.4 MB 368 kB/s    | 9.6 MB 877 kB/s
# Requirement already satisfied: ipython_genutils in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-contrib-nbextensions==0.5.3) (0.2.0)
# Requirement already satisfied: jupyter_contrib_core>=0.3.3 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-contrib-nbextensions==0.5.3) (0.3.3)
# Requirement already satisfied: jupyter_core in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-contrib-nbextensions==0.5.3) (4.7.1)
# Requirement already satisfied: jupyter_highlight_selected_word>=0.1.1 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-contrib-nbextensions==0.5.3) (0.2.0)
# Requirement already satisfied: jupyter_latex_envs>=1.4.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-contrib-nbextensions==0.5.3) (1.4.6)
# Requirement already satisfied: jupyter_nbextensions_configurator>=0.4.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-contrib-nbextensions==0.5.3) (0.4.1)
# Requirement already satisfied: nbconvert>=6.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-contrib-nbextensions==0.5.3) (6.1.0)
# Requirement already satisfied: notebook>=6.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-contrib-nbextensions==0.5.3) (6.4.3)
# Requirement already satisfied: tornado in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-contrib-nbextensions==0.5.3) (6.1)
# Requirement already satisfied: traitlets>=4.1 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-contrib-nbextensions==0.5.3) (5.0.5)
# Requirement already satisfied: lxml in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-contrib-nbextensions==0.5.3) (4.8.0)
# Requirement already satisfied: setuptools in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter_contrib_core>=0.3.3->jupyter-contrib-nbextensions==0.5.3) (57.4.0)
# Requirement already satisfied: ipython in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (7.26.0)
# Requirement already satisfied: pyyaml in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions==0.5.3) (6.0)
# Requirement already satisfied: testpath in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (2.10.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.5.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.8.4)
# Requirement already satisfied: nbformat>=4.4 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (5.1.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.3)
# Requirement already satisfied: jinja2>=2.4 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (3.0.1)
# Requirement already satisfied: bleach in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (4.0.0)
# Requirement already satisfied: defusedxml in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (1.4.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jinja2>=2.4->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (2.0.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (7.0.1)
# Requirement already satisfied: nest-asyncio in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (22.2.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from nbformat>=4.4->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.18.0)
# Requirement already satisfied: six>=1.11.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (21.2.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.11.1)
# Requirement already satisfied: prometheus-client in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.11.0)
# Requirement already satisfied: ipykernel in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (6.2.0)
# Requirement already satisfied: argon2-cffi in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (20.1.0)
# Requirement already satisfied: ptyprocess in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from terminado>=0.8.3->notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from argon2-cffi->notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (1.14.6)
# Requirement already satisfied: pycparser in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (2.20)
# Requirement already satisfied: packaging in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from bleach->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (21.0)
# Requirement already satisfied: webencodings in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from bleach->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.5.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipykernel->notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (1.4.1)
# Requirement already satisfied: appnope in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipykernel->notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.1.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipykernel->notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.1.2)
# Requirement already satisfied: decorator in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (5.0.9)
# Requirement already satisfied: jedi>=0.16 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (0.18.0)
# Requirement already satisfied: pickleshare in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (4.8.0)
# Requirement already satisfied: backcall in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from jedi>=0.16->ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (0.8.2)
# Requirement already satisfied: wcwidth in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (0.2.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from packaging->bleach->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (2.4.7)
# Building wheels for collected packages: jupyter-contrib-nbextensions
#   Building wheel for jupyter-contrib-nbextensions (setup.py) ... done
#   Created wheel for jupyter-contrib-nbextensions: filename=jupyter_contrib_nbextensions-0.5.3-py2.py3-none-any.whl size=23430542 sha256=0266976f5dad330d00a584c658d7745ff5b67be6bee125808b19f22f241b39c4
#   Stored in directory: /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-ephem-wheel-cache-mkw2zuxa/wheels/13/bc/41/8f4309864399b9536d850bb7629b05e08c244c64dd210b4b84
# Successfully built jupyter-contrib-nbextensions
# Installing collected packages: jupyter-contrib-nbextensions
#   Attempting uninstall: jupyter-contrib-nbextensions
#     Found existing installation: jupyter-contrib-nbextensions 0.5.1
#     Uninstalling jupyter-contrib-nbextensions-0.5.1:
#       Successfully uninstalled jupyter-contrib-nbextensions-0.5.1
# Successfully installed jupyter-contrib-nbextensions-0.5.3
# Note: you may need to restart the kernel to use updated packages.
